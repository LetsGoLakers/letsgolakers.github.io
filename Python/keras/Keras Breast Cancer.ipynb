# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
from keras import Sequential
from keras.layers import Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
cancer = load_breast_cancer()
x = cancer['data']
y = cancer['target']
x_train, x_test, y_train, y_test = train_test_split(x,y)
scaler = StandardScaler()
scaler.fit(x_train)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
print(x_train.shape)
model = Sequential()
# Out:
# (426, 30)

# %%
model.add(Dense(30,input_dim = 30))
model.add(Dense(30,activation = 'relu'))
model.add(Dense(30,activation = 'relu'))
model.add(Dense(30,activation = "linear"))
model.add(Dense(1,activation='sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.fit(x_train,y_train,batch_size = 426,epochs = 100,verbose = 1)
print(model.evaluate(x_test,y_test))
predictions = model.predict(x_test)
# Out:
# Epoch 1/100
# 426/426 [==============================] - 4s 10ms/step - loss: 0.7165 - acc: 0.3709
# Epoch 2/100
# 426/426 [==============================] - 0s 41us/step - loss: 0.7057 - acc: 0.0047
# Epoch 3/100
# 426/426 [==============================] - 0s 38us/step - loss: 0.6960 - acc: 0.0047
# Epoch 4/100
# 426/426 [==============================] - 0s 47us/step - loss: 0.6868 - acc: 0.6291
# Epoch 5/100
# 426/426 [==============================] - 0s 47us/step - loss: 0.6786 - acc: 0.6291
# Epoch 6/100
# 426/426 [==============================] - 0s 38us/step - loss: 0.6707 - acc: 0.6291
# Epoch 7/100
# 426/426 [==============================] - 0s 56us/step - loss: 0.6630 - acc: 0.6291
# Epoch 8/100
# 426/426 [==============================] - 0s 47us/step - loss: 0.6554 - acc: 0.6291
# Epoch 9/100
# 426/426 [==============================] - 0s 47us/step - loss: 0.6481 - acc: 0.6291
# Epoch 10/100
# ...

# %%
predictions.reshape(143)
# Out:
# array([ 0.9897396 ,  0.9897396 ,  0.9897396 ,  0.9897396 ,  0.9897396 ,
#         0.9897396 ,  0.9897396 ,  0.9897396 ,  0.9897396 ,  0.03268838,
#         0.03268838,  0.03268838,  0.9897396 ,  0.9897396 ,  0.9897396 ,
#         0.03268838,  0.9897396 ,  0.9897396 ,  0.9897396 ,  0.9897396 ,
#         0.9897396 ,  0.03268838,  0.9897396 ,  0.03268838,  0.9897396 ,
#         0.03268838,  0.03268838,  0.9897396 ,  0.03268838,  0.9897396 ,
#         0.03268838,  0.9897396 ,  0.03268838,  0.9897396 ,  0.03268838,
#         0.9897396 ,  0.03268838,  0.03268838,  0.9897396 ,  0.9897396 ,
#         0.9897396 ,  0.9897396 ,  0.9897396 ,  0.9897396 ,  0.9897396 ,
#         0.03268838,  0.03268838,  0.9897396 ,  0.9897396 ,  0.9897396 ,
#         0.9897396 ,  0.9897396 ,  0.9897396 ,  0.03268838,  0.9897396 ,
#         0.9897396 ,  0.9897396 ,  0.9897396 ,  0.03268838,  0.9897396 ,
#         0.03268838,  0.9897396 ,  0.03268838,  0.9897396 ,  0.9897396 ,
# ...

# %%
error = 0
def compare(index):
    global error
    diff = round(y_test[index]-predictions[index][0])
    print("Ideal: " + str(y_test[index]) +" Predicted: " + str((predictions[index][0])) + " Difference: "+str(diff))
    if diff > 0.1 or diff < -0.1:
        error = error + 1

# %%
for i in range(len(predictions)):
    compare(i)
# Out:
# Ideal: 1 Predicted: 0.98974 Difference: 0.0
# Ideal: 1 Predicted: 0.98974 Difference: 0.0
# Ideal: 1 Predicted: 0.98974 Difference: 0.0
# Ideal: 1 Predicted: 0.98974 Difference: 0.0
# Ideal: 1 Predicted: 0.98974 Difference: 0.0
# Ideal: 1 Predicted: 0.98974 Difference: 0.0
# Ideal: 1 Predicted: 0.98974 Difference: 0.0
# Ideal: 1 Predicted: 0.98974 Difference: 0.0
# Ideal: 1 Predicted: 0.98974 Difference: 0.0
# Ideal: 0 Predicted: 0.0326884 Difference: -0.0
# Ideal: 0 Predicted: 0.0326884 Difference: -0.0
# Ideal: 0 Predicted: 0.0326884 Difference: -0.0
# Ideal: 1 Predicted: 0.98974 Difference: 0.0
# Ideal: 1 Predicted: 0.98974 Difference: 0.0
# Ideal: 1 Predicted: 0.98974 Difference: 0.0
# Ideal: 0 Predicted: 0.0326884 Difference: -0.0
# Ideal: 1 Predicted: 0.98974 Difference: 0.0
# Ideal: 1 Predicted: 0.98974 Difference: 0.0
# Ideal: 1 Predicted: 0.98974 Difference: 0.0
# Ideal: 1 Predicted: 0.98974 Difference: 0.0
# Ideal: 0 Predicted: 0.98974 Difference: -1.0
# ...

# %%
print(model.predict(x_test[139].reshape(1,30)))
print(y_test[139])
# Out:
# [[ 0.9897396]]
# 0
